# %% [markdown]
# Problem 1

# %%
import pandas as pd
df_msas = pd.read_csv("msas.csv")
df_msas.head()
# Out:
#     CBSA                         NAME  POPESTIMATE2017
# 0  10180                  Abilene, TX           170219
# 1  10420                    Akron, OH           703505
# 2  10500                   Albany, GA           151434
# 3  10540                   Albany, OR           125047
# 4  10580  Albany-Schenectady-Troy, NY           886188

# %%
# get all geo id from cbsa
geoid = "31000US" + dfRaw["CBSA"].astype(str)

# %%
first = geoid[:len(geoid)//2]
second = geoid[len(geoid)//2:]
# join list together in a way that the api accepts
first = ','.join(first)
second = ','.join(second)

# %%
# HH income 
table_income = ['B19001']
table_income_string = ','.join(table_income)

# %%
requesturl = 'http://api.censusreporter.org/1.0/data/show/latest?table_ids=%s&geo_ids=%s' % (table_income_string, first)
loadedjson = requests.get(requesturl)
parsedjson_first = json.loads(loadedjson.text)
parsedjson_first
requesturl = 'http://api.censusreporter.org/1.0/data/show/latest?table_ids=%s&geo_ids=%s' % (table_income_string, second)
loadedjson = requests.get(requesturl)
parsedjson_second = json.loads(loadedjson.text)
parsedjson_second
# Out:
# {'data': {'31000US29420': {'B19001': {'error': {'B19001001': 2751.0,
#      'B19001002': 1247.0,
#      'B19001003': 1281.0,
#      'B19001004': 1209.0,
#      'B19001005': 1452.0,
#      'B19001006': 1562.0,
#      'B19001007': 1135.0,
#      'B19001008': 1267.0,
#      'B19001009': 1534.0,
#      'B19001010': 1194.0,
#      'B19001011': 1700.0,
#      'B19001012': 1548.0,
#      'B19001013': 1855.0,
#      'B19001014': 1039.0,
#      'B19001015': 1029.0,
#      'B19001016': 980.0,
#      'B19001017': 704.0},
#     'estimate': {'B19001001': 87565.0,
#      'B19001002': 6721.0,
#      'B19001003': 5748.0,
#      'B19001004': 5621.0,
#      'B19001005': 6472.0,
#      'B19001006': 6374.0,
#      'B19001007': 4798.0,
#      'B19001008': 4467.0,
#      'B19001009': 5862.0,
#      'B19001010': 3749.0,
#      'B19001011': 8735.0,
#      'B19001012': 7195.0,
#      'B19001013': 9628.0,
#      'B19001014': 3559.0,
#      'B19001015': 3777.0,
#      'B19001016': 2773.0,
# ...

# %%
df_income = pd.DataFrame(columns=['country id', 'population number'], index=list(range(1,len(geoid))))

# %%
for i in list(range(1,len(geoid)//2)):
    df_income['country id'][i]=[geoid[i]]
    df_income['population number'][i] = parsedjson_first['data'][geoid[i]]['B19001']['estimate']['B19001011'] + parsedjson_first['data'][geoid[i]]['B19001']['estimate']['B19001012']
    
for i in list(range(192,len(geoid))):
    df_income['country id'][i]=[geoid[i]]
    df_income['population number'][i] = parsedjson_second['data'][geoid[i]]['B19001']['estimate']['B19001011'] + parsedjson_second['data'][geoid[i]]['B19001']['estimate']['B19001012']

# %%
df_income.loc[df_income['population number'] == max(df_income['population number'])]
# Out:
#          country id population number
# 249  [31000US35620]       1.03819e+06

# %%
df_msas.loc[dfRaw['CBSA'] == 35620]
# Out:
#       CBSA                                   NAME  POPESTIMATE2017
# 249  35620  New York-Newark-Jersey City, NY-NJ-PA         20320876

# %% [markdown]
# problem 2

# %%
# age population
table_age = ['B01001']
table_age_string = ','.join(table_age)

# %%
requesturl = 'http://api.censusreporter.org/1.0/data/show/latest?table_ids=%s&geo_ids=%s' % (table_age_string, first)
loadedjson = requests.get(requesturl)
parsedjson_first = json.loads(loadedjson.text)
parsedjson_first
requesturl = 'http://api.censusreporter.org/1.0/data/show/latest?table_ids=%s&geo_ids=%s' % (table_age_string, second)
loadedjson = requests.get(requesturl)
parsedjson_second = json.loads(loadedjson.text)
parsedjson_second
# Out:
# {'data': {'31000US29420': {'B01001': {'error': {'B01001001': 0.0,
#      'B01001002': 956.0,
#      'B01001003': 669.0,
#      'B01001004': 1173.0,
#      'B01001005': 1175.0,
#      'B01001006': 396.0,
#      'B01001007': 617.0,
#      'B01001008': 462.0,
#      'B01001009': 514.0,
#      'B01001010': 538.0,
#      'B01001011': 733.0,
#      'B01001012': 532.0,
#      'B01001013': 1420.0,
#      'B01001014': 1246.0,
#      'B01001015': 411.0,
#      'B01001016': 551.0,
#      'B01001017': 1201.0,
#      'B01001018': 790.0,
#      'B01001019': 1070.0,
#      'B01001020': 822.0,
#      'B01001021': 1022.0,
#      'B01001022': 977.0,
#      'B01001023': 1017.0,
#      'B01001024': 766.0,
#      'B01001025': 876.0,
#      'B01001026': 956.0,
#      'B01001027': 564.0,
#      'B01001028': 1020.0,
#      'B01001029': 873.0,
#      'B01001030': 401.0,
#      'B01001031': 645.0,
#      'B01001032': 370.0,
#      'B01001033': 505.0,
#      'B01001034': 744.0,
#      'B01001035': 835.0,
# ...

# %%
df_age = pd.DataFrame(columns=['country id', 'age'], index=list(range(1,len(geoid))))

# %%
for i in list(range(1,len(geoid)//2)):
    df_age['country id'][i]=[geoid[i]]
    df_age['age'][i] = parsedjson_first['data'][geoid[i]]['B01001']['estimate']['B01001007'] + parsedjson_first['data'][geoid[i]]['B01001']['estimate']['B01001008'] +parsedjson_first['data'][geoid[i]]['B01001']['estimate']['B01001009']+parsedjson_first['data'][geoid[i]]['B01001']['estimate']['B01001010']+parsedjson_first['data'][geoid[i]]['B01001']['estimate']['B01001011']+parsedjson_first['data'][geoid[i]]['B01001']['estimate']['B01001012']
    
for i in list(range(192,len(geoid))):
    df_age['country id'][i]=[geoid[i]]
    df_age['age'][i] = parsedjson_second['data'][geoid[i]]['B01001']['estimate']['B01001007'] + parsedjson_second['data'][geoid[i]]['B01001']['estimate']['B01001008'] +parsedjson_second['data'][geoid[i]]['B01001']['estimate']['B01001009']+parsedjson_second['data'][geoid[i]]['B01001']['estimate']['B01001010']+parsedjson_second['data'][geoid[i]]['B01001']['estimate']['B01001011']+parsedjson_second['data'][geoid[i]]['B01001']['estimate']['B01001012']

# %%
df_age.loc[df_age['age'] == max(df_age['age'])]
# Out:
#          country id          age
# 249  [31000US35620]  2.40159e+06

# %%
df_msas.loc[df_msas['CBSA'] == 35620]
# Out:
#       CBSA                                   NAME  POPESTIMATE2017
# 249  35620  New York-Newark-Jersey City, NY-NJ-PA         20320876

# %% [markdown]
# problem # 3

# %%
# Hispanic population
table_hispanic = ['B03003']
table_hispanic_string = ','.join(table_hispanic)

# %%
requesturl = 'http://api.censusreporter.org/1.0/data/show/latest?table_ids=%s&geo_ids=%s' % (table_hispanic_string, first)
loadedjson = requests.get(requesturl)
parsedjson_first = json.loads(loadedjson.text)
parsedjson_first
requesturl = 'http://api.censusreporter.org/1.0/data/show/latest?table_ids=%s&geo_ids=%s' % (table_hispanic_string, second)
loadedjson = requests.get(requesturl)
parsedjson_second = json.loads(loadedjson.text)
parsedjson_second
# Out:
# {'data': {'31000US29420': {'B03003': {'error': {'B03003001': 0.0,
#      'B03003002': 0.0,
#      'B03003003': 0.0},
#     'estimate': {'B03003001': 207200.0,
#      'B03003002': 173137.0,
#      'B03003003': 34063.0}}},
#   '31000US29460': {'B03003': {'error': {'B03003001': 0.0,
#      'B03003002': 0.0,
#      'B03003003': 0.0},
#     'estimate': {'B03003001': 686483.0,
#      'B03003002': 533370.0,
#      'B03003003': 153113.0}}},
#   '31000US29540': {'B03003': {'error': {'B03003001': 0.0,
#      'B03003002': 0.0,
#      'B03003003': 0.0},
#     'estimate': {'B03003001': 542903.0,
#      'B03003002': 485644.0,
#      'B03003003': 57259.0}}},
#   '31000US29620': {'B03003': {'error': {'B03003001': 0.0,
#      'B03003002': 0.0,
#      'B03003003': 0.0},
#     'estimate': {'B03003001': 477656.0,
#      'B03003002': 445857.0,
#      'B03003003': 31799.0}}},
#   '31000US29700': {'B03003': {'error': {'B03003001': 0.0,
#      'B03003002': 0.0,
#      'B03003003': 0.0},
# ...

# %%
df_hispanic = pd.DataFrame(columns=['country id', 'hispanic amount'], index=list(range(1,len(geoid))))

# %%
for i in list(range(1,len(geoid)//2)):
    df_hispanic['country id'][i]=[geoid[i]]
    df_hispanic['hispanic amount'][i] = parsedjson_first['data'][geoid[i]]['B03003']['estimate']['B03003003']
    
for i in list(range(192,len(geoid))):
    df_hispanic['country id'][i]=[geoid[i]]
    df_hispanic['hispanic amount'][i] = parsedjson_second['data'][geoid[i]]['B03003']['estimate']['B03003003']

# %%
df_hispanic.loc[df_hispanic['hispanic amount'] == max(df_hispanic['hispanic amount'])]
# Out:
#          country id hispanic amount
# 210  [31000US31080]     6.03149e+06

# %%
df_msas.loc[df_msas['CBSA'] ==31080]
# Out:
#       CBSA                                NAME  POPESTIMATE2017
# 210  31080  Los Angeles-Long Beach-Anaheim, CA         13353907

# %% [markdown]
# problem #4

# %%
# df_income

# %%
max(df_income['population number'])
# Out:
# 1038188.0

# %%
# for income
# highest population in income : 20320876 in newyork
tem_income = []
i = 1
while(i < 381):
    a = df_income['population number'][i]
    b = df_income['population number'][249]
    c = a/b
    d = '{:.2%}'.format(float(c))
   
    e = float(d.strip('%'))
    tem_income.append(e)
    i +=1

# %%
tem_age = []
i = 1
while(i < 381):
    a = df_age['age'][i]
    b = df_age['age'][249]
    c = a/b
    d = '{:.2%}'.format(float(c))
   
    e = float(d.strip('%'))
    tem_age.append(e)
    i +=1

tem_age
# Out:
# [3.42,
#  0.71,
#  0.54,
#  4.49,
#  4.42,
#  0.7,
#  3.79,
#  0.53,
#  1.33,
#  1.03,
#  2.33,
#  2.58,
#  0.51,
#  1.06,
#  1.78,
#  1.36,
#  27.9,
#  1.2,
#  1.11,
#  2.98,
#  12.19,
#  5.15,
#  13.56,
#  0.8,
#  0.76,
#  4.51,
#  0.56,
#  0.45,
#  2.04,
#  0.5,
#  1.25,
#  0.74,
#  0.75,
#  1.25,
#  5.2,
#  0.67,
#  1.42,
#  1.09,
#  1.37,
#  0.41,
#  3.46,
#  25.24,
#  2.03,
#  1.04,
#  1.53,
#  4.14,
#  2.05,
#  0.44,
#  5.49,
#  0.71,
#  1.28,
#  0.54,
#  1.68,
#  2.78,
#  0.49,
#  0.79,
#  0.26,
#  0.37,
#  1.29,
#  0.61,
#  1.82,
#  0.87,
#  4.06,
#  11.71,
#  1.24,
#  2.5,
#  0.51,
#  47.02,
#  1.31,
#  10.38,
#  1.92,
#  0.57,
#  9.13,
#  0.65,
#  2.21,
#  4.28,
#  1.22,
#  4.38,
#  1.76,
#  0.43,
#  10.82,
#  2.26,
#  0.73,
#  1.42,
#  0.52,
#  36.75,
#  0.68,
#  0.34,
#  0.85,
#  1.63,
#  3.81,
#  0.67,
#  0.44,
#  2.64,
#  15.13,
#  3.1,
#  19.57,
#  0.61,
#  0.86,
#  0.49,
#  1.37,
#  2.95,
#  0.78,
#  0.9,
#  1.07,
#  0.7,
#  0.94,
#  0.41,
#  4.82,
#  0.32,
#  1.34,
# ...

# %%
tem_hispainc = []
i = 1
while(i < 381):
    a = df_hispanic['hispanic amount'][i]
    b = df_hispanic['hispanic amount'][249]
    c = a/b
    d = '{:.2%}'.format(float(c))
   
    e = float(d.strip('%'))
    tem_hispainc.append(e)
    i +=1

# %%
average = [(a+b+c)/3 for a,b,c in zip(tem_income,tem_age,tem_hispainc)]
# len(average)


average.insert(0, 0)

# %%
df_average = pd.DataFrame(columns=['average'], index=list(range(1,len(average))))
for i in range(1,len(average)):
    df_average['average'][i]=[average[i]]
df_average.stack().index[np.argmax(df_average.values)]
# Out:
# (249, 'average')

# %%
df_msas.loc[249]
# Out:
# CBSA                                               35620
# NAME               New York-Newark-Jersey City, NY-NJ-PA
# POPESTIMATE2017                                 20320876
# Name: 249, dtype: object
